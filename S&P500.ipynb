# %%
import FinanceDataReader as fdr
import pandas as pd

#  차트 설정
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = 'nanummyeongjo'
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams["axes.grid"] = True

# %%
# S&P 500 index, 2015~Now
df = fdr.DataReader('US500', '2015-01-01')
df['SMA50'] = pd.Series(df['Close'].rolling(50).mean(), index=df.index) 
df['SMA200'] = pd.Series(df['Close'].rolling(200).mean(), index=df.index)

df[['Close','SMA50','SMA200']].plot(figsize = (16,8))

# %%
df.tail()
# Out:
#               Close     Open     High      Low  Volume  Change      SMA50  \
# Date
# 2019-05-02  2917.52  2922.16  2931.68  2900.50     0.0 -0.0021  2848.7828
# 2019-05-03  2945.64  2929.21  2947.85  2929.21     0.0  0.0096  2852.1980
# 2019-05-06  2932.47  2908.89  2937.32  2898.21     0.0 -0.0045  2854.9940
# 2019-05-07  2884.05  2913.03  2913.03  2862.60     0.0 -0.0165  2856.7528
# 2019-05-08  2879.42  2879.61  2897.96  2873.28     0.0 -0.0016  2858.4632
#
#                 SMA200
# Date
# 2019-05-02  2773.36570
# 2019-05-03  2774.04615
# 2019-05-06  2774.63040
# 2019-05-07  2775.02820
# 2019-05-08  2775.41615

# %%
df_all = fdr.DataReader('US500')
df_all.tail()
# Out:
#               Close     Open     High      Low  Volume  Change
# Date
# 2019-05-15  2850.96  2820.38  2858.68  2815.08     0.0  0.0058
# 2019-05-16  2876.32  2855.80  2892.15  2855.80     0.0  0.0089
# 2019-05-17  2859.53  2858.60  2885.48  2854.23     0.0 -0.0058
# 2019-05-20  2840.23  2841.94  2853.86  2831.29     0.0 -0.0067
# 2019-05-21  2864.36  2854.02  2868.88  2854.02     0.0  0.0085

# %%
df_all.head()
# Out:
#               Close     Open     High      Low  Volume  Change
# Date
# 2010-01-04  1132.99  1116.56  1133.87  1116.56     0.0  0.0160
# 2010-01-05  1136.52  1132.66  1136.63  1129.66     0.0  0.0031
# 2010-01-06  1137.14  1135.71  1139.19  1133.95     0.0  0.0005
# 2010-01-07  1141.69  1136.27  1142.46  1131.32     0.0  0.0040
# 2010-01-08  1144.98  1140.52  1145.39  1136.22     0.0  0.0029
